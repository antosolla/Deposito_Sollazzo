# %%
print("ciao",1,12,"ciao","arrivederci")
# Out:
# ciao 1 12 ciao arrivederci

# %%
intero = 8

floatMy = 1.5

print(intero +floatMy)
print(intero -floatMy)
print(intero /floatMy)
print(intero *floatMy)
print(intero **floatMy)
print(intero %floatMy)
# Out:
# 9.5
# 6.5
# 5.333333333333333
# 12.0
# 22.627416997969522
# 0.5

# %%
print(5 //3)
# Out:
# 1

# %%
print("mi chiamo Tommaso e la mia età è "+str(39)+" anni")
# Out:
# mi chiamo Tommaso e la mia età è 39 anni

# %%
valore = "mi chiamo Tommaso e la mia età è",39,"anni"

valore2= "mi chiamo Tommaso e la mia età è "+str(39)+" anni"

valore3= f"mi chiamo Tommaso e la mia età è {2026-1987} anni"

print("valore",type(valore))
print("valore2",type(valore2))
print("valore3",type(valore3))
# Out:
# valore <class 'tuple'>
# valore2 <class 'str'>
# valore3 <class 'str'>

# %%
print("mi chiamo Tommaso e la mia età è",39,"anni")
# Out:
# mi chiamo Tommaso e la mia età è 39 anni

# %%
num, num2 = 1,2

print(num2)
# Out:
# 2

# %%
eta = 39

Patente = True

Bevuto = False


if eta >= 18:
    if Patente:
        if not Bevuto:
            print("puoi guidare")
        else:
            print("non puoi guidare perchè hai bevuto")
    else:
        print("non puoi guidare perchè non hai la patente")
else:
    print("non puoi guidare perchè sei minorenne")
# Out:
# puoi guidare

# %%
if eta < 18:
    print("non puoi guidare perchè sei minorenne")
elif not Patente:
    print("non puoi guidare perchè non hai la patente")
elif Bevuto:
    print("non puoi guidare perchè hai bevuto")
else:
    print("puoi guidare")

# %%
eta = 15

variabile = "maggiorenne" if eta >=18 else "minorenne"

print(variabile)
# Out:
# minorenne

# %%
count = 0

while count < 5:
    print("ciao")
    count +=1
# Out:
# ciao
# ciao
# ciao
# ciao
# ciao

# %%
while True:
    numero = input("inserisci un numero: ")
    if numero.isdecimal():
        print("è un numero")
        break
    else:
        print("Hai inserito un numero non valido")

print("proseguo programma")
# Out:
# Hai inserito un numero non valido
# è un numero
# proseguo programma

# %%
count = 10
while count >0:
    count -=1
    if count == 5:
        print("continue")
        continue
    print(count)
    print("ciclo normale")
# Out:
# 9
# ciclo normale
# 8
# ciclo normale
# 7
# ciclo normale
# 6
# ciclo normale
# continue
# 4
# ciclo normale
# 3
# ciclo normale
# 2
# ciclo normale
# 1
# ciclo normale
# 0
# ciclo normale

# %%
var = "ciao"

lista = [1, 1.8, "ciao", [1,2,3]]

print(lista[-2])
# Out:
# ciao

# %%
lista = ["zero","uno","due","tre","quattro","cinque"]

lista2 = lista[::2]

print(lista2)
# Out:
# ['zero', 'due', 'quattro']

# %%
var = "ciao"
var2 = var

# %%
lista = [1,2,3]
lista2 = lista
lista.pop()

print(lista2)
# Out:
# [1, 2]

# %%
lista = [1,2,3]
lista2 = lista[:]
lista.pop()

print(lista2)
# Out:
# [1, 2, 3]

# %%
lista = ["zero","uno","due","tre","quattro","cinque"]

#lista.append("sei")
lista.insert(0,"meno uno")

print(lista.index("uno"))
# Out:
# 2

# %%
lista = ["zero","uno","due","tre","quattro","cinque"]

lista2 = ["sei","sette"]

print(lista.extend(lista2))

print(lista)
# Out:
# None
# ['zero', 'uno', 'due', 'tre', 'quattro', 'cinque', 'sei', 'sette']

# %%
lista = [12,6,3,11,7,5,1]

lista.sort(reverse=True)

print(lista)
# Out:
# [12, 11, 7, 6, 5, 3, 1]

# %%
lista = ["zero","uno","due","tre","quattro","cinque"]

print(lista.pop(1))

print(lista)
# Out:
# uno
# ['zero', 'due', 'tre', 'quattro', 'cinque']

# %%
lista = ["zero","uno","due","tre","quattro","cinque"]

lista.remove("due")

print(lista)
# Out:
# ['zero', 'uno', 'tre', 'quattro', 'cinque']

# %%
lista = ["zero","uno","due","tre","quattro","cinque"]

del lista[2]
print(lista)
# Out:
# ['zero', 'uno', 'tre', 'quattro', 'cinque']

# %%
lista = ["zero","uno","due","tre","quattro","cinque","uno"]

#lista[2] = "ciao"

print(lista.count("uno"))
# Out:
# 2

# %%
stringa = "ciao a tutti"

print(stringa.startswith("ciao"))

print(stringa.endswith("tutti"))
# Out:
# True
# True

# %%
stringa = "ciao11 a11tutti"

print(stringa.isalnum())
# Out:
# False

# %%
stringa = "11aa"
print(stringa.isdecimal())
# Out:
# False

# %%
stringa = "aa"
print(stringa.isalpha())
# Out:
# True

# %%
numero = input("inserisci un numero:")

if numero.isdecimal():
    print("numero valido")
else:
    print("numero non valido")
# Out:
# numero valido

# %%
stringa = "CiAo A tUtti"

print(stringa.upper())

print(stringa.lower())
# Out:
# CIAO A TUTTI
# ciao a tutti

# %%
stringa = "ciao a tutti"

stringa =stringa.replace("nessuno","qualcuno")

print(stringa)
# Out:
# ciao a tutti

# %%
stringa = "ciao a tutti"

print(stringa.count("a"))
# Out:
# 2

# %%
stringa = "tommaso-teresa-michele-alfredo"

lista = stringa.split("-")
print(lista)
# Out:
# ['tommaso', 'teresa', 'michele', 'alfredo']

# %%
lista = ["tommaso","teresa","michele","alfredo"]

sep = "-"

stringa = sep.join(lista)

print(stringa)
# Out:
# tommaso-teresa-michele-alfredo

# %%
stringa = "tommaso-teresa-michele-alfredo"

print(stringa[-1])
# Out:
# o

# %%
stringa2= stringa[2:7]

print(stringa2)
# Out:
# mmaso

# %%
lista = ["tommaso","teresa","michele","alfredo"]
stringa = "tommaso teresa michele alfredo"

print("tom" in lista)
print("tom" in stringa)
# Out:
# False
# True

# %%
lista = ["tommaso","teresa","michele","alfredo"]
stringa = "tommaso teresa michele alfredo"

for nome in lista:
    print(nome)
# Out:
# tommaso
# teresa
# michele
# alfredo

# %%
print(list(range(1,5,2)))
# Out:
# [1, 3]

# %%
for count in "12345":
    print("ciao")
# Out:
# ciao
# ciao
# ciao
# ciao
# ciao

# %%
count = 5
while count > 0:
    print("ciao")
    count-=1
# Out:
# ciao
# ciao
# ciao
# ciao
# ciao

# %%
lista = ["tommaso","teresa","michele","alfredo"]

for nome in lista:
    print(nome)
# Out:
# tommaso
# teresa
# michele
# alfredo

# %%
lista = ["tommaso","teresa","michele","alfredo"]

i = 0

while i < len(lista):
    print(lista[i])
    i+=1
# Out:
# tommaso
# teresa
# michele
# alfredo

# %%
lista = [1,2,3,4,5,6]

lista2 = []

for num in lista:
    if num%2 == 0:
        lista2.append(num)

print(lista2)
# Out:
# [2, 4, 6]

# %%
lista = [1,2,3,4,5,6]

lista2 = [str(num) for num in lista]

#lista2 = [num for num in lista if num%2==0]

print(lista2)
# Out:
# ['1', '2', '3', '4', '5', '6']

# %%
lista = ["mela","banana","ciliegia","melone"]

lista2=[elemento for elemento in lista if "a" in elemento ]

print(lista2)
# Out:
# ['mela', 'banana', 'ciliegia']

# %%
stringa = "ciao"
var = "si" if "a" in stringa else "no"

print(var)
# Out:
# si

# %%
lista = [1,2,3,4,5,6,6,"ciao"]

tupla = (1,2,3,4,5,6,6,"ciao")

setMy = {1,2,3,4,5,6,6,"ciao",7}
print(lista)
print(tupla)
setMy.add("14")
print(setMy)
#print(lista[0])
#print(tupla[0])
#print(setMy[0])
# Out:
# [1, 2, 3, 4, 5, 6, 6, 'ciao']
# (1, 2, 3, 4, 5, 6, 6, 'ciao')
# {1, 2, 3, 4, 5, 6, 7, '14', 'ciao'}
