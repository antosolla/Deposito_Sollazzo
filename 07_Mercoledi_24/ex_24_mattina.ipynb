# %% [markdown]
# Tommaso Muraca 24/06/2026 10:01 •
# Scrivete un programma che chiede una stringa all’utente e
# restituisce un dizionario rappresentante la "frequenza di comparsa" di ciascuna vocale componente la stringa.
# Esempio:
# Stringa "ababcc",
# Risultato
# {"a": 2}
